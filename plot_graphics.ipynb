# %%
import pandas as pd
database = pd.read_excel('database_TCC.xlsx')
# database = database[['A','E','N','Rt']]
database.rename(columns={'A': 'H', 'E': 't'}, inplace=True)
database
# Out:
#     CASES   H  t      Area   N  hconv      Nu    Tmax     Rt        UA  \
# 0       1  25  1  0.260047  11  27.20   78.62   67.67  1.638  0.610501
# 1       3  25  1  0.118203   5  35.45  102.00  126.85  2.595  0.385356
# 2       5  25  2  0.378251   8  29.88   91.57   72.71  1.976  0.506073
# 3       7  25  3  0.780142  11  10.00   31.00  162.85  4.164  0.240154
# 4       9  25  3  0.354610   5  29.00   88.97   94.85  2.869  0.348554
# 5      11  35  1  0.189125   8  31.60   96.90   61.15  1.421  0.703730
# 6      13  35  2  0.520095  11  20.15   61.80   63.03  1.564  0.639386
# 7      15  35  2  0.236407   5  30.40   93.30   77.35  2.101  0.475964
# 8      17  35  3  0.567376   8  25.10   76.90   63.25  1.591  0.628536
# 9       2  25  1  0.189125   8  32.08   98.34   76.30  1.946  0.513875
# 10      6  25  2  0.236407   5  29.24   89.62   98.76  2.991  0.334336
# 11     16  35  3  0.780142  11  10.27   31.47   94.70  2.896  0.345304
#
#        Afin
# 0   0.02103
# 1   0.01087
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Y = 'Nu'

# plt.figure(figsize=(15, 8))
# plt.subplot(1, 3, 1)
# sns.regplot(data = database,x="A",y=Y)
# plt.subplot(1, 3, 2)
# sns.regplot(data = database,x="E",y=Y)
# plt.subplot(1, 3, 3)
# sns.regplot(data = database,x="N",y=Y)

# %% [markdown]
# # NU

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="N", y='Nu',hue="E",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="N", y='Nu',hue="A",data=database,ci=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\vinao\OneDrive\Documents\Github\predictive_fin_performance\predictive_fin_performance\plot_graphics.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/vinao/OneDrive/Documents/Github/predictive_fin_performance/predictive_fin_performance/plot_graphics.ipynb#ch0000004?line=0'>1</a> plt.figure(figsize=(15, 8))
#       <a href='vscode-notebook-cell:/c%3A/Users/vinao/OneDrive/Documents/Github/predictive_fin_performance/predictive_fin_performance/plot_graphics.ipynb#ch0000004?line=1'>2</a> plt.subplot(1, 2, 1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vinao/OneDrive/Documents/Github/predictive_fin_performance/predictive_fin_performance/plot_graphics.ipynb#ch0000004?line=2'>3</a> sns.lineplot(x="N", y='Nu',hue="E",data=database,ci=None)
# ...

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="E", y='Nu',hue="N",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="E", y='Nu',hue="A",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Nu'>

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="A", y='Nu',hue="N",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="A", y='Nu',hue="E",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='A', ylabel='Nu'>

# %% [markdown]
# # TMAX

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="N", y='Tmax',hue="E",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="N", y='Tmax',hue="A",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='N', ylabel='Tmax'>

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="E", y='Tmax',hue="N",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="E", y='Tmax',hue="A",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Tmax'>

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="A", y='Tmax',hue="N",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="A", y='Tmax',hue="E",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='A', ylabel='Tmax'>

# %% [markdown]
# # RT

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="N", y='Rt',hue="E",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="N", y='Rt',hue="A",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='N', ylabel='Rt'>

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="E", y='Rt',hue="N",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="E", y='Rt',hue="A",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Rt'>

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.lineplot(x="A", y='Rt',hue="N",data=database,ci=None)

plt.subplot(1, 2, 2)
sns.lineplot(x="A", y='Rt',hue="E",data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='A', ylabel='Rt'>

# %% [markdown]
# # NO HUE

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 3, 1)
sns.lineplot(x="N", y='Nu',data=database,ci=None)

plt.subplot(1, 3, 2)
sns.lineplot(x="t", y='Nu',data=database,ci=None)

plt.subplot(1, 3, 3)
sns.lineplot(x="H", y='Nu',data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Nu'>

# %%
sns.catplot(x="N", y='Nu',data=database, kind="point")

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 3, 1)
sns.lineplot(x="N", y='Tmax',data=database,ci=None)

plt.subplot(1, 3, 2)
sns.lineplot(x="t", y='Tmax',data=database,ci=None)

plt.subplot(1, 3, 3)
sns.lineplot(x="H", y='Tmax',data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Tmax'>

# %%
sns.catplot(x="H", y='Tmax',data=database, kind="point")

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 3, 1)
sns.lineplot(x="N", y='Rt',data=database,ci=None)

plt.subplot(1, 3, 2)
sns.lineplot(x="t", y='Rt',data=database,ci=None)

plt.subplot(1, 3, 3)
sns.lineplot(x="H", y='Rt',data=database,ci=None)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Rt'>

# %%
sns.catplot(x="N", y='Rt',data=database, kind="point")

# %%
import pandas as pd
dic = {"Num Elementos":[43261,46218,78784,169986,281226,764841,1195272,3399723,5281132],"Ts":[70.6,69.97,68.5,66.24,66.26,63.1,63.5,63.63,63.68]}
valores_malha_nos = pd.DataFrame(dic)
valores_malha_nos
# Out:
#    Num Elementos     Ts
# 0          43261  70.60
# 1          46218  69.97
# 2          78784  68.50
# 3         169986  66.24
# 4         281226  66.26
# 5         764841  63.10
# 6        1195272  63.50
# 7        3399723  63.63
# 8        5281132  63.68

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.interpolate import UnivariateSpline


import seaborn as sns

plt.figure(figsize=(10,5))
fexp = UnivariateSpline(valores_malha_nos["Num Elementos"], valores_malha_nos["Ts"], k=5)

sns.lineplot(x=valores_malha_nos["Num Elementos"], y=fexp(valores_malha_nos["Num Elementos"]),ci=None)
plt.ylim([60, 75])

plt.show()

# %%
dic = {"Num Elementos":[80090,141424,238643,1160877,1732511,2600880,2611559,3170434],"Ts":[86.94,74.64,69.81,69.73,69.35,68.88,68.94,69.12]}
valores_malha_vitor = pd.DataFrame(dic)

# %%
sns.lineplot(x="Num Elementos", y='Ts',data=valores_malha_vitor,ci=None)
# Out:
# <AxesSubplot:xlabel='Num Elementos', ylabel='Ts'>

# %%
import pandas as pd
dic = {"Re":[7500,10000,15500,23000],"Texp":[77.1,68,56.7,47.8],"Tnum":[74.95,63.35,53.55,46.75],"Nuexp":[53.4,67.3,89.3,115.1],"Nunum":[64.6,83.1,112.9,143.1]}
validacao = pd.DataFrame(dic)

# %%
validacao
# Out:
#       Re  Texp   Tnum  Nuexp  Nunum
# 0   7500  77.1  74.95   53.4   64.6
# 1  10000  68.0  63.35   67.3   83.1
# 2  15500  56.7  53.55   89.3  112.9
# 3  23000  47.8  46.75  115.1  143.1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.lineplot(x="Re", y='Texp',data=validacao,ci=None,linestyle='--')
sns.lineplot(x="Re", y='Tnum',data=validacao,ci=None,linestyle='-')
plt.legend(['Experimental (MASCHIETTO, 2018)', 'Presente Trabalho'])
plt.ylabel('Tmax')
plt.xlabel('Reynolds')
# Out:
# Text(0.5, 0, 'Reynolds')

# %%
from scipy.interpolate import interp1d
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# plt.plot(validacao["Re"], validacao["Texp"], '--')
# plt.plot(validacao["Re"], validacao["Tnum"], '--')

fexp = interp1d(validacao["Re"], validacao['Texp'], kind='cubic')
plt.plot(validacao["Re"], fexp(validacao["Re"]), '--')


fnum = interp1d(validacao["Re"], validacao['Tnum'], kind='cubic')
plt.plot(validacao["Re"], fnum(validacao["Re"]), '-')

# sns.lineplot(x="Re", y='Texp',data=validacao,ci=None,linestyle='--')
# sns.lineplot(x="Re", y='Tnum',data=validacao,ci=None,linestyle='-')
plt.legend(['Experimental (MASCHIETTO, 2018)', 'Presente Trabalho'])
plt.ylabel('Tmax')
plt.xlabel('Reynolds')

plt.show()

# %%
from scipy.interpolate import interp1d
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline


plt.figure(figsize=(10,6))

# plt.plot(validacao["Re"], validacao["Texp"], '--')
# plt.plot(validacao["Re"], validacao["Tnum"], '--')


fexp = UnivariateSpline(validacao["Re"], validacao['Texp'], k = 3)
# fexp = interp1d(validacao["Re"], validacao['Texp'], kind='cubic')
plt.plot(validacao["Re"], fexp(validacao["Re"]), '--')


fnum = UnivariateSpline(validacao["Re"], validacao['Tnum'], k = 3)
plt.plot(validacao["Re"], fnum(validacao["Re"]), '-')

# sns.lineplot(x="Re", y='Texp',data=validacao,ci=None,linestyle='--')
# sns.lineplot(x="Re", y='Tnum',data=validacao,ci=None,linestyle='-')
plt.legend(['Experimental (MASCHIETTO, 2018)', 'Presente Trabalho'])
plt.ylabel('Tmax')
plt.xlabel('Reynolds')

plt.show()

# %%
from scipy.interpolate import interp1d
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
from scipy.interpolate import make_interp_spline
from scipy.ndimage import gaussian_filter1d

plt.figure(figsize=(10,6))

# plt.plot(validacao["Re"], validacao["Texp"], '--')
# plt.plot(validacao["Re"], validacao["Tnum"], '--')


fexp = make_interp_spline(validacao["Re"], validacao['Texp'])
# fexp = interp1d(validacao["Re"], validacao['Texp'], kind='cubic')
plt.plot(validacao["Re"], gaussian_filter1d(validacao['Texp'], sigma=1), '--')


fnum = make_interp_spline(validacao["Re"], validacao['Tnum'])
plt.plot(validacao["Re"], gaussian_filter1d(validacao['Tnum'], sigma=1), '-')

# sns.lineplot(x="Re", y='Texp',data=validacao,ci=None,linestyle='--')
# sns.lineplot(x="Re", y='Tnum',data=validacao,ci=None,linestyle='-')
plt.legend(['Experimental (MASCHIETTO, 2018)', 'Presente Trabalho'])
plt.ylabel('Tmax')
plt.xlabel('Reynolds')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.lineplot(x="Re", y='Nuexp',data=validacao,ci=None,linestyle='--')
sns.lineplot(x="Re", y='Nunum',data=validacao,ci=None,linestyle='-')
plt.legend(['Experimental (MASCHIETTO, 2018)', 'Presente Trabalho'])
plt.ylabel('Nusselt')
plt.xlabel('Reynolds')
# Out:
# Text(0.5, 0, 'Reynolds')
